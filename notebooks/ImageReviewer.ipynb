# %%
import numpy as np
import nrrd

# %%
readdata, header = nrrd.read('/Users/baymac/Documents/Kaggle/imageData/resampled/train/00000/FLAIR.nrrd')
print(readdata.)
# Out:
# [[[0.02778567 0.02778567 0.02778567 ... 0.02778567 0.02778567 0.02778567]
#   [0.02778567 0.02778567 0.02778567 ... 0.02778567 0.02778567 0.02778567]
#   [0.02778567 0.02778567 0.02778567 ... 0.02778567 0.02778567 0.02778567]
#   ...
#   [0.02778567 0.02778567 0.02778567 ... 0.02778567 0.02778567 0.02778567]
#   [0.02778567 0.02778567 0.02778567 ... 0.02778567 0.02778567 0.02778567]
#   [0.02778567 0.02778567 0.02778567 ... 0.02778567 0.02778567 0.02778567]]
#
#  [[0.02778567 0.02778567 0.02778567 ... 0.02778567 0.02778567 0.02778567]
#   [0.02778567 0.02778567 0.02778567 ... 0.02778567 0.02778567 0.02778567]
#   [0.02778567 0.02778567 0.02778567 ... 0.02778567 0.02778567 0.02778567]
#   ...
#   [0.02778567 0.02778567 0.02778567 ... 0.02778567 0.02778567 0.02778567]
#   [0.02778567 0.02778567 0.02778567 ... 0.02778567 0.02778567 0.02778567]
#   [0.02778567 0.02778567 0.02778567 ... 0.02778567 0.02778567 0.02778567]]
#
# ...
